# %% [markdown]
# # AST 7939 Week 5

# %% [markdown]
# ## Regression methods

# %% [markdown]
# ### [Regression with DT](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)

# %%
import numpy as np

# Quadratic training set + noise
np.random.seed(42)
m = 200
X = np.random.rand(m, 1)
y = 4 * (X - 0.5) ** 2
y = y + np.random.randn(m, 1) / 10

# %%
import matplotlib.pyplot as plt 

plt.scatter(X,y)

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

tree_reg1 = DecisionTreeRegressor(random_state=42, max_depth=2)
tree_reg2 = DecisionTreeRegressor(random_state=42, max_depth=3)

tree_reg1.fit(X, y)
tree_reg2.fit(X, y)

def plot_regression_predictions(tree_reg, X, y, axes=[0, 1, -0.2, 1], ylabel="$y$"):
    x1 = np.linspace(axes[0], axes[1], 500).reshape(-1, 1)
    y_pred = tree_reg.predict(x1)
    plt.axis(axes)
    plt.xlabel("$x_1$", fontsize=18)
    if ylabel:
        plt.ylabel(ylabel, fontsize=18, rotation=0)
    plt.plot(X, y, "b.")
    plt.plot(x1, y_pred, "r.-", linewidth=2, label=r"$\hat{y}$")

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plot_regression_predictions(tree_reg1, X, y)
for split, style in ((0.1973, "k-"), (0.0917, "k--"), (0.7718, "k--")):
    plt.plot([split, split], [-0.2, 1], style, linewidth=2)
plt.text(0.21, 0.65, "Depth=0", fontsize=15)
plt.text(0.01, 0.2, "Depth=1", fontsize=13)
plt.text(0.65, 0.8, "Depth=1", fontsize=13)
plt.legend(loc="upper center", fontsize=18)
plt.title("max_depth=2", fontsize=14)

plt.sca(axes[1])
plot_regression_predictions(tree_reg2, X, y, ylabel=None)
for split, style in ((0.1973, "k-"), (0.0917, "k--"), (0.7718, "k--")):
    plt.plot([split, split], [-0.2, 1], style, linewidth=2)
for split in (0.0458, 0.1298, 0.2873, 0.9040):
    plt.plot([split, split], [-0.2, 1], "k:", linewidth=1)
plt.text(0.3, 0.5, "Depth=2", fontsize=13)
plt.title("max_depth=3", fontsize=14)
# Out:
# Text(0.5, 1.0, 'max_depth=3')

# %%
tree_reg1.predict([[0.5]])
# Out:
# array([0.11063973])

# %%
tree_reg1 = DecisionTreeRegressor(random_state=42)
tree_reg2 = DecisionTreeRegressor(random_state=42, min_samples_leaf=10)
tree_reg1.fit(X, y)
tree_reg2.fit(X, y)

x1 = np.linspace(0, 1, 500).reshape(-1, 1)
y_pred1 = tree_reg1.predict(x1)
y_pred2 = tree_reg2.predict(x1)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plt.plot(X, y, "b.")
plt.plot(x1, y_pred1, "r.-", linewidth=2, label=r"$\hat{y}$")
plt.axis([0, 1, -0.2, 1.1])
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", fontsize=18, rotation=0)
plt.legend(loc="upper center", fontsize=18)
plt.title("No restrictions", fontsize=14)

plt.sca(axes[1])
plt.plot(X, y, "b.")
plt.plot(x1, y_pred2, "r.-", linewidth=2, label=r"$\hat{y}$")
plt.axis([0, 1, -0.2, 1.1])
plt.xlabel("$x_1$", fontsize=18)
plt.title("min_samples_leaf={}".format(tree_reg2.min_samples_leaf), fontsize=14)
# Out:
# Text(0.5, 1.0, 'min_samples_leaf=10')

# %% [markdown]
# ### [Regression with kNN](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors

np.random.seed(0)
X = np.sort(5 * np.random.rand(40, 1), axis=0)
T = np.linspace(0, 5, 500)[:, np.newaxis]
y = np.sin(X).ravel()

# Add noise
y[::5] += 1 * (0.5 - np.random.rand(8))

# %%
n_neighbors = 5

for i, weights in enumerate(["uniform", "distance"]):
    knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
    knn.fit(X, y)
    y_ = knn.predict(T)
    
    plt.subplot(2, 1, i + 1)
    plt.scatter(X, y, color="darkorange", label="data")
    plt.plot(T, y_, color="navy", label="prediction")
    plt.axis("tight")
    plt.legend()
    plt.title("KNeighborsRegressor (k = %i, weights = '%s')" % (n_neighbors, weights))

plt.tight_layout()
plt.show()

# %%
knn.predict([[1.5]])
# Out:
# array([0.89712051])

# %% [markdown]
# ### [Regression with SVM](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html)

# %% [markdown]
# ### Here's an example of linear SVR.

# %%
np.random.seed(42)
m = 50
X = 2 * np.random.rand(m, 1)
y = (4 + 3 * X + np.random.randn(m, 1)).ravel()

# %%
plt.scatter(X, y)

# %%
from sklearn.svm import LinearSVR

# You need to specify desired epsilon.
# Here, I'm making two linear SVR models, one with epsilon=1.5 and the other with epsilon=0.5.

svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)
svm_reg2 = LinearSVR(epsilon=0.5, random_state=42)
svm_reg1.fit(X, y)
svm_reg2.fit(X, y)

# To visualize the support vectors.
def find_support_vectors(svm_reg, X, y):
    y_pred = svm_reg.predict(X)
    off_margin = (np.abs(y - y_pred) >= svm_reg.epsilon)
    return np.argwhere(off_margin)

svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)
svm_reg2.support_ = find_support_vectors(svm_reg2, X, y)

eps_x1 = 1
eps_y_pred = svm_reg1.predict([[eps_x1]])

# %%
def plot_svm_regression(svm_reg, X, y, axes):
    x1s = np.linspace(axes[0], axes[1], 100).reshape(100, 1)
    y_pred = svm_reg.predict(x1s)
    plt.plot(x1s, y_pred, "k-", linewidth=2, label=r"$\hat{y}$")
    plt.plot(x1s, y_pred + svm_reg.epsilon, "k--")
    plt.plot(x1s, y_pred - svm_reg.epsilon, "k--")
    plt.scatter(X[svm_reg.support_], y[svm_reg.support_], s=180, facecolors='#FFAAAA')
    plt.plot(X, y, "bo")
    plt.xlabel(r"$x_1$", fontsize=18)
    plt.axis(axes)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plot_svm_regression(svm_reg1, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg1.epsilon), fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)
plt.annotate(
        '', xy=(eps_x1, eps_y_pred), xycoords='data',
        xytext=(eps_x1, eps_y_pred - svm_reg1.epsilon),
        textcoords='data', arrowprops={'arrowstyle': '<->', 'linewidth': 1.5}
    )
plt.text(0.85, 5.5, r"$\epsilon$", fontsize=20)
plt.sca(axes[1])
plot_svm_regression(svm_reg2, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg2.epsilon), fontsize=18)
# Out:
# Text(0.5, 1.0, '$\\epsilon = 0.5$')

# %% [markdown]
# ### And here's an example of non-linear SVR

# %%
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = np.sin(X).ravel()
# Add noise
y[::5] += 3 * (0.5 - np.random.rand(8))

# %%
plt.scatter(X, y)

# %%
from sklearn.svm import SVR

# I'm making three polynomial SVR models.

svm_poly1 = SVR(kernel="poly", degree=1, C=100, epsilon=0.1, coef0=1.)
svm_poly2 = SVR(kernel="poly", degree=2, C=100, epsilon=0.1, coef0=1.)
svm_poly3 = SVR(kernel="poly", degree=3, C=100, epsilon=0.1, coef0=1.)

svm_poly1.fit(X, y)
svm_poly2.fit(X, y)
svm_poly3.fit(X, y)
# Out:
# SVR(C=100, coef0=1.0, kernel='poly')

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 4), sharey=True)

plt.sca(axes[0])
plot_svm_regression(svm_poly1, X, y, [0, 5, -1.5, 2.5])
plt.title("First-degree polynomial", fontsize=18)
plt.ylabel(r"$y$", fontsize=18)

plt.sca(axes[1])
plot_svm_regression(svm_poly2, X, y, [0, 5, -1.5, 2.5])
plt.title("Second-degree polynomial", fontsize=18)

plt.sca(axes[2])
plot_svm_regression(svm_poly3, X, y, [0, 5, -1.5, 2.5])
plt.title("Third-degree polynomial", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Third-degree polynomial')

# %% [markdown]
# ### TODO: Hyperparameter optimization
#
# Optimize hyperparameters (C, gamma) for SVR with "rbf" kernel and epsilon=0.1.

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{'gamma': [1e-4, 1e-3, 0.01, 0.1, 1.0, 10.0, 100., 1000.],
               'C': [1, 10, 100, 1000, 10000]}
             ]
svr_gs = GridSearchCV(SVR(kernel='rbf', epsilon=0.1), parameters, cv=5, verbose=3)
svr_gs.fit(X, y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END ...............C=1, gamma=0.0001;, score=-16.487 total time=   0.0s
# [CV 2/5] END ................C=1, gamma=0.0001;, score=-6.359 total time=   0.0s
# [CV 3/5] END ................C=1, gamma=0.0001;, score=-0.376 total time=   0.0s
# [CV 4/5] END ...............C=1, gamma=0.0001;, score=-10.468 total time=   0.0s
# [CV 5/5] END ...............C=1, gamma=0.0001;, score=-11.760 total time=   0.0s
# [CV 1/5] END ................C=1, gamma=0.001;, score=-14.278 total time=   0.0s
# [CV 2/5] END .................C=1, gamma=0.001;, score=-5.873 total time=   0.0s
# [CV 3/5] END .................C=1, gamma=0.001;, score=-0.174 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.001;, score=-9.468 total time=   0.0s
# [CV 5/5] END ................C=1, gamma=0.001;, score=-10.291 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.01;, score=-1.555 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.01;, score=-3.530 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.01;, score=-0.106 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.01;, score=-4.084 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.01;, score=-2.003 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=0.1;, score=-0.340 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=0.1;, score=-1.076 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.532 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=0.1;, score=-0.824 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=0.1;, score=-0.119 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=1.0;, score=-6.677 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=1.0;, score=-0.816 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=1.0;, score=0.290 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=1.0;, score=-0.343 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=1.0;, score=-1.298 total time=   0.0s
# [CV 1/5] END .................C=1, gamma=10.0;, score=-13.777 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=10.0;, score=-2.426 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=10.0;, score=-0.062 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=10.0;, score=-3.412 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=10.0;, score=-6.486 total time=   0.0s
# [CV 1/5] END ................C=1, gamma=100.0;, score=-17.364 total time=   0.0s
# [CV 2/5] END .................C=1, gamma=100.0;, score=-4.091 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=100.0;, score=0.337 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=100.0;, score=-7.321 total time=   0.0s
# [CV 5/5] END .................C=1, gamma=100.0;, score=-9.073 total time=   0.0s
# [CV 1/5] END ...............C=1, gamma=1000.0;, score=-18.988 total time=   0.0s
# [CV 2/5] END ................C=1, gamma=1000.0;, score=-5.965 total time=   0.0s
# [CV 3/5] END ................C=1, gamma=1000.0;, score=-0.011 total time=   0.0s
# [CV 4/5] END ................C=1, gamma=1000.0;, score=-6.843 total time=   0.0s
# [CV 5/5] END ................C=1, gamma=1000.0;, score=-8.794 total time=   0.0s
# [CV 1/5] END ..............C=10, gamma=0.0001;, score=-14.261 total time=   0.0s
# [CV 2/5] END ...............C=10, gamma=0.0001;, score=-5.871 total time=   0.0s
# [CV 3/5] END ...............C=10, gamma=0.0001;, score=-0.170 total time=   0.0s
# [CV 4/5] END ...............C=10, gamma=0.0001;, score=-9.457 total time=   0.0s
# [CV 5/5] END ..............C=10, gamma=0.0001;, score=-10.283 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=0.001;, score=-1.461 total time=   0.0s
# [CV 2/5] END ................C=10, gamma=0.001;, score=-3.684 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.001;, score=-0.163 total time=   0.0s
# [CV 4/5] END ................C=10, gamma=0.001;, score=-3.864 total time=   0.0s
# [CV 5/5] END ................C=10, gamma=0.001;, score=-1.920 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=0.01;, score=-5.528 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.01;, score=-1.620 total time=   0.0s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.455 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.01;, score=-1.532 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.01;, score=-0.746 total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=0.1;, score=-1.713 total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=0.1;, score=-0.827 total time=   0.0s
# [CV 3/5] END ..................C=10, gamma=0.1;, score=-0.013 total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=0.1;, score=-0.578 total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=0.1;, score=-1.523 total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=1.0;, score=-6.942 total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=1.0;, score=-0.802 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=1.0;, score=0.218 total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=1.0;, score=-0.166 total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=1.0;, score=-0.586 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=10.0;, score=-10.560 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=10.0;, score=-2.029 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=10.0;, score=-8.369 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=10.0;, score=-4.468 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=10.0;, score=-7.870 total time=   0.0s
# [CV 1/5] END ...............C=10, gamma=100.0;, score=-17.526 total time=   0.0s
# [CV 2/5] END ................C=10, gamma=100.0;, score=-4.068 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=100.0;, score=-0.053 total time=   0.0s
# [CV 4/5] END ................C=10, gamma=100.0;, score=-7.233 total time=   0.0s
# [CV 5/5] END ................C=10, gamma=100.0;, score=-8.731 total time=   0.0s
# [CV 1/5] END ..............C=10, gamma=1000.0;, score=-21.279 total time=   0.0s
# [CV 2/5] END ...............C=10, gamma=1000.0;, score=-6.356 total time=   0.0s
# [CV 3/5] END ...............C=10, gamma=1000.0;, score=-1.985 total time=   0.0s
# [CV 4/5] END ...............C=10, gamma=1000.0;, score=-6.344 total time=   0.0s
# [CV 5/5] END ...............C=10, gamma=1000.0;, score=-7.320 total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=0.0001;, score=-1.455 total time=   0.0s
# [CV 2/5] END ..............C=100, gamma=0.0001;, score=-3.628 total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=0.0001;, score=-0.167 total time=   0.0s
# [CV 4/5] END ..............C=100, gamma=0.0001;, score=-3.842 total time=   0.0s
# [CV 5/5] END ..............C=100, gamma=0.0001;, score=-1.916 total time=   0.0s
# [CV 1/5] END ...............C=100, gamma=0.001;, score=-4.641 total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=0.001;, score=-1.957 total time=   0.0s
# [CV 3/5] END ................C=100, gamma=0.001;, score=0.335 total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=0.001;, score=-1.590 total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=0.001;, score=-0.334 total time=   0.0s
# [CV 1/5] END ...............C=100, gamma=0.01;, score=-15.941 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.01;, score=-1.488 total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.483 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=0.01;, score=-1.490 total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.01;, score=-2.865 total time=   0.0s
# [CV 1/5] END .................C=100, gamma=0.1;, score=-2.130 total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.1;, score=-0.596 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.357 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.1;, score=-0.442 total time=   0.0s
# [CV 5/5] END .................C=100, gamma=0.1;, score=-0.294 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=1.0;, score=-12.611 total time=   0.0s
# [CV 2/5] END .................C=100, gamma=1.0;, score=-0.849 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=1.0;, score=0.388 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=1.0;, score=-0.445 total time=   0.0s
# [CV 5/5] END .................C=100, gamma=1.0;, score=-0.791 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=10.0;, score=-7.590 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=10.0;, score=-1.465 total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=10.0;, score=-111.748 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=10.0;, score=-8.091 total time=   0.0s
# [CV 5/5] END ................C=100, gamma=10.0;, score=-9.271 total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=100.0;, score=-20.163 total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=100.0;, score=-4.622 total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=100.0;, score=-64.113 total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=100.0;, score=-7.241 total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=100.0;, score=-8.032 total time=   0.0s
# [CV 1/5] END .............C=100, gamma=1000.0;, score=-22.920 total time=   0.0s
# [CV 2/5] END ..............C=100, gamma=1000.0;, score=-6.548 total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=1000.0;, score=-9.482 total time=   0.0s
# [CV 4/5] END ..............C=100, gamma=1000.0;, score=-5.972 total time=   0.0s
# [CV 5/5] END ..............C=100, gamma=1000.0;, score=-6.517 total time=   0.0s
# [CV 1/5] END .............C=1000, gamma=0.0001;, score=-4.545 total time=   0.0s
# [CV 2/5] END .............C=1000, gamma=0.0001;, score=-1.996 total time=   0.0s
# [CV 3/5] END ..............C=1000, gamma=0.0001;, score=0.309 total time=   0.0s
# [CV 4/5] END .............C=1000, gamma=0.0001;, score=-1.735 total time=   0.0s
# [CV 5/5] END .............C=1000, gamma=0.0001;, score=-0.342 total time=   0.0s
# [CV 1/5] END ..............C=1000, gamma=0.001;, score=-7.955 total time=   0.0s
# [CV 2/5] END ..............C=1000, gamma=0.001;, score=-1.692 total time=   0.0s
# [CV 3/5] END ...............C=1000, gamma=0.001;, score=0.453 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=0.001;, score=-1.566 total time=   0.0s
# [CV 5/5] END ..............C=1000, gamma=0.001;, score=-0.976 total time=   0.0s
# [CV 1/5] END ..............C=1000, gamma=0.01;, score=-18.455 total time=   0.0s
# [CV 2/5] END ...............C=1000, gamma=0.01;, score=-1.324 total time=   0.0s
# [CV 3/5] END ................C=1000, gamma=0.01;, score=0.524 total time=   0.0s
# [CV 4/5] END ...............C=1000, gamma=0.01;, score=-1.198 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=0.01;, score=-5.504 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=0.1;, score=-18.039 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=0.1;, score=-0.488 total time=   0.0s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.395 total time=   0.0s
# [CV 4/5] END ................C=1000, gamma=0.1;, score=-0.294 total time=   0.0s
# [CV 5/5] END ................C=1000, gamma=0.1;, score=-0.225 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=1.0;, score=-22.125 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=1.0;, score=-0.617 total time=   0.0s
# [CV 3/5] END .................C=1000, gamma=1.0;, score=0.318 total time=   0.0s
# [CV 4/5] END .................C=1000, gamma=1.0;, score=0.002 total time=   0.0s
# [CV 5/5] END ................C=1000, gamma=1.0;, score=-0.673 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=10.0;, score=-8.989 total time=   0.0s
# [CV 2/5] END ..............C=1000, gamma=10.0;, score=-10.264 total time=   0.0s
# [CV 3/5] END .............C=1000, gamma=10.0;, score=-794.840 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=10.0;, score=-21.299 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=10.0;, score=-8.210 total time=   0.0s
# [CV 1/5] END .............C=1000, gamma=100.0;, score=-44.482 total time=   0.0s
# [CV 2/5] END ..............C=1000, gamma=100.0;, score=-9.868 total time=   0.0s
# [CV 3/5] END ............C=1000, gamma=100.0;, score=-434.198 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=100.0;, score=-6.650 total time=   0.0s
# [CV 5/5] END ..............C=1000, gamma=100.0;, score=-7.610 total time=   0.0s
# [CV 1/5] END ............C=1000, gamma=1000.0;, score=-22.920 total time=   0.0s
# [CV 2/5] END .............C=1000, gamma=1000.0;, score=-6.548 total time=   0.0s
# [CV 3/5] END .............C=1000, gamma=1000.0;, score=-9.482 total time=   0.0s
# [CV 4/5] END .............C=1000, gamma=1000.0;, score=-5.972 total time=   0.0s
# [CV 5/5] END .............C=1000, gamma=1000.0;, score=-6.517 total time=   0.0s
# [CV 1/5] END ............C=10000, gamma=0.0001;, score=-5.698 total time=   0.0s
# [CV 2/5] END ............C=10000, gamma=0.0001;, score=-1.963 total time=   0.0s
# [CV 3/5] END .............C=10000, gamma=0.0001;, score=0.340 total time=   0.0s
# [CV 4/5] END ............C=10000, gamma=0.0001;, score=-1.575 total time=   0.0s
# [CV 5/5] END ............C=10000, gamma=0.0001;, score=-0.591 total time=   0.0s
# [CV 1/5] END ............C=10000, gamma=0.001;, score=-20.561 total time=   0.0s
# [CV 2/5] END .............C=10000, gamma=0.001;, score=-1.559 total time=   0.0s
# [CV 3/5] END ..............C=10000, gamma=0.001;, score=0.466 total time=   0.0s
# [CV 4/5] END .............C=10000, gamma=0.001;, score=-1.667 total time=   0.0s
# [CV 5/5] END .............C=10000, gamma=0.001;, score=-3.173 total time=   0.0s
# [CV 1/5] END ..............C=10000, gamma=0.01;, score=-9.797 total time=   0.0s
# [CV 2/5] END ..............C=10000, gamma=0.01;, score=-0.939 total time=   0.0s
# [CV 3/5] END ...............C=10000, gamma=0.01;, score=0.315 total time=   0.0s
# [CV 4/5] END ..............C=10000, gamma=0.01;, score=-0.686 total time=   0.0s
# [CV 5/5] END ..............C=10000, gamma=0.01;, score=-3.745 total time=   0.0s
# [CV 1/5] END ..............C=10000, gamma=0.1;, score=-50.041 total time=   0.0s
# [CV 2/5] END ...............C=10000, gamma=0.1;, score=-0.447 total time=   0.0s
# [CV 3/5] END ................C=10000, gamma=0.1;, score=0.477 total time=   0.0s
# [CV 4/5] END ...............C=10000, gamma=0.1;, score=-0.043 total time=   0.0s
# [CV 5/5] END ...............C=10000, gamma=0.1;, score=-0.883 total time=   0.0s
# [CV 1/5] END ..............C=10000, gamma=1.0;, score=-13.352 total time=   0.1s
# [CV 2/5] END ...............C=10000, gamma=1.0;, score=-0.788 total time=   0.1s
# [CV 3/5] END ................C=10000, gamma=1.0;, score=0.295 total time=   0.1s
# [CV 4/5] END ...............C=10000, gamma=1.0;, score=-0.314 total time=   0.0s
# [CV 5/5] END ...............C=10000, gamma=1.0;, score=-2.369 total time=   0.0s
# [CV 1/5] END .............C=10000, gamma=10.0;, score=-28.929 total time=   0.0s
# [CV 2/5] END .............C=10000, gamma=10.0;, score=-49.349 total time=   0.0s
# [CV 3/5] END ...........C=10000, gamma=10.0;, score=-6143.084 total time=   0.0s
# [CV 4/5] END ............C=10000, gamma=10.0;, score=-868.414 total time=   0.1s
# [CV 5/5] END ............C=10000, gamma=10.0;, score=-144.799 total time=   0.0s
# [CV 1/5] END ............C=10000, gamma=100.0;, score=-84.674 total time=   0.0s
# [CV 2/5] END ............C=10000, gamma=100.0;, score=-12.031 total time=   0.0s
# [CV 3/5] END ...........C=10000, gamma=100.0;, score=-425.673 total time=   0.0s
# [CV 4/5] END .............C=10000, gamma=100.0;, score=-2.706 total time=   0.0s
# [CV 5/5] END .............C=10000, gamma=100.0;, score=-5.545 total time=   0.0s
# [CV 1/5] END ...........C=10000, gamma=1000.0;, score=-22.920 total time=   0.0s
# [CV 2/5] END ............C=10000, gamma=1000.0;, score=-6.548 total time=   0.0s
# [CV 3/5] END ............C=10000, gamma=1000.0;, score=-9.482 total time=   0.0s
# [CV 4/5] END ............C=10000, gamma=1000.0;, score=-5.972 total time=   0.0s
# [CV 5/5] END ............C=10000, gamma=1000.0;, score=-6.517 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid=[{'C': [1, 10, 100, 1000, 10000],
#                           'gamma': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                     1000.0]}],
#              verbose=3)

# %%
svr_gs.best_estimator_
# Out:
# SVR(C=1, gamma=0.1)

# %%
plot_svm_regression(svr_gs.best_estimator_, X, y, [0, 5, -1.5, 2.5])

plt.title("Gaussian RBF (best model)", fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# ### TODO (optional): Bitcoin challenge for extra credit?!
#
# Make a regression model and submit your prediction for 2023 March (daily BTC price), by the last day of 2023 February via Canvas. In the first week of 2023 April, I will compute your scores (metric = [mean squared error](https://en.wikipedia.org/wiki/Mean_squared_error)). The winner will get +5 pts in your final homework score. The next three will get +2 pts in your homework score.

# %%
# !pip install pandas-datareader

import pandas_datareader
from pandas_datareader import data

btc = data.DataReader('CBBTCUSD', start='2004', end='2024', data_source="fred")
btc
# Out:
#             CBBTCUSD
# DATE
# 2014-12-01    370.00
# 2014-12-02    378.00
# 2014-12-03    378.00
# 2014-12-04    377.10
# 2014-12-05       NaN
# ...              ...
# 2023-02-03  23426.40
# 2023-02-04  23318.95
# 2023-02-05  22938.03
# 2023-02-06  22751.79
# 2023-02-07  23260.42
#
# [2991 rows x 1 columns]

# %%
btc = btc.dropna()
btc
# Out:
#             CBBTCUSD
# DATE
# 2014-12-01    370.00
# 2014-12-02    378.00
# 2014-12-03    378.00
# 2014-12-04    377.10
# 2014-12-06    378.00
# ...              ...
# 2023-02-03  23426.40
# 2023-02-04  23318.95
# 2023-02-05  22938.03
# 2023-02-06  22751.79
# 2023-02-07  23260.42
#
# [2956 rows x 1 columns]

# %%
plt.plot(btc['CBBTCUSD'])
plt.xlabel('Date')
plt.ylabel('Price [USD]')
# Out:
# Text(0, 0.5, 'Price [USD]')
